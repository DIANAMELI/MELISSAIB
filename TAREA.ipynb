# %%
import pandas as pd

# %%
# !ls
# Out:
# Untitled.ipynb	libro1.txt  libro2.txt	libro3.txt  prueba.ipynb

# %%
with open ('libro1.txt') as f:
    libro1 = f.read()

# %%
 with open ('libro2.txt') as f:
    libro2 = f.read()

# %%
with open ('libro3.txt') as f:
    libro3 = f.read()

# %%
# !ls
# Out:
# Untitled.ipynb	libro1.txt  libro2.txt	libro3.txt  prueba.ipynb

# %%
print(libro1)
print(libro2)
print(libro3)
# Out:
# ﻿The Project Gutenberg EBook of Another Earth, by David Evans and Al Landau
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org/license
#
#
# Title: Another Earth
#
# Author: David Evans
#         Al Landau
#
# Release Date: February 10, 2020 [EBook #61367]
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK ANOTHER EARTH ***
#
#
#
#
# Produced by Greg Weeks, Mary Meehan and the Online
# Distributed Proofreading Team at http://www.pgdp.net
#
#
#
#
#
#
#
#
#
#                              ANOTHER EARTH
#
#                       BY DAVID EVANS & AL LANDAU
#
#                Whatever it was that had happened in the
#                test, it badly needed a good explanation.
#
#            [Transcriber's Note: This etext was produced from
# ...

# %%
num_pal = len(libro1.split(' '))
num_pal = len(libro2.split(' '))
num_pal = len(libro3.split(' '))

# %%
libro1.split(' ')
libro2.split(' ')
libro3.split(' ')
# Out:
# ['\ufeffProject',
#  "Gutenberg's",
#  'The',
#  'Boy',
#  'Travellers',
#  'in',
#  'Mexico,',
#  'by',
#  'Thomas',
#  'W.',
#  'Knox\n\nThis',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most\nother',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions\nwhatsoever.',
#  '',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of\nthe',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at\nwww.gutenberg.org.',
#  '',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States,',
#  "you'll",
#  'have\nto',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
# ...

# %%
print("Los libros tienen " + str(num_pal) + " palabras")
# Out:
# Los libros tienen 163044 palabras

# %%
type(num_pal)
# Out:
# int

# %%
guardar_string = str(num_pal)

# %%
type(guardar_string)
# Out:
# str

# %%
num_pal_unic = len(set(libro1.split(' ')))
num_pal_unic = len(set(libro2.split(' ')))
num_pal_unic = len(set(libro3.split(' ')))

# %%
print("Los libros tiene " + str(num_pal_unic) + " palabras únicas")
# Out:
# Los libros tiene 30318 palabras únicas

# %%
set(libro1.split(' '))
set(libro2.split(' '))
set(libro3.split(' '))
# Out:
# {'',
#  'REDUCING',
#  'a\npicoté',
#  'indorse',
#  'ecclesiastical',
#  'redress',
#  'uses.',
#  'EPISCOPAL',
#  'slippery',
#  'is\nthirty-nine',
#  'ropes.',
#  'down,',
#  'announces',
#  "Family'",
#  "'mountain",
#  'exclaimed',
#  'origin;',
#  'castle;',
#  'pianos',
#  'exacted',
#  'and\nthey',
#  'Molino\nwas',
#  'PLANTING',
#  'declined\nthe',
#  '100\n',
#  'dollars.\'\n\n"\'Very',
#  'change',
#  'westward,',
#  'employed',
#  'revenue',
#  'slide',
#  'Spanish\nAmerica,"',
#  'metals\nsufficient',
#  'IN',
#  'Iztaccihuatl',
#  'at\nonce',
#  "MAXIMILIAN.--MAX'S",
#  'CURIOUS',
#  'idols',
#  'travellers',
#  'DEFEAT',
#  'of\nOrizaba',
#  'travellers\ngo',
#  'then\nthe',
#  'palaces,',
#  'thinks',
#  'discovered.\nAbout',
#  'land-leeches',
#  'are\nindiscriminately',
#  'aloud',
#  'nightly',
#  'flood,',
#  'clear\nthat',
#  'Ploughman',
#  'maguey;',
#  'chile',
#  'Mayapan,',
#  'therefore\nentirely',
#  'the\nexcavations',
#  'States."\n\n[Illustration:',
# ...

# %%
print ( 
    ", ".join(
    
    )


)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-5d8d825b60b8> in <module>
#       1 print (
# ----> 2     ", ".join(
#       3
#       4     )
#       5
#
# TypeError: join() takes exactly one argument (0 given)

# %%
df_ili = pd.DataFrame({'palabras': libro1.split(' '), "ocurrencia":1})
df_ili = pd.DataFrame({'palabras': libro2.split(' '), "ocurrencia":1})
df_ili = pd.DataFrame({'palabras': libro3.split(' '), "ocurrencia":1})

# %%
df_ili.head()
# Out:
#       palabras  ocurrencia
# 0     ﻿Project           1
# 1  Gutenberg's           1
# 2          The           1
# 3          Boy           1
# 4   Travellers           1

# %%
print(", ".join(df_ili.groupby('palabras').count().sort_values(by='ocurrencia', ascending=False).head(20).index.tolist()))
# Out:
# , the, of, and, to, a, in, is, was, that, it, for, as, by, they, with, are, were, at, or

# %%
df_ili.head(20)
# Out:
#         palabras  ocurrencia
# 0       ﻿Project           1
# 1    Gutenberg's           1
# 2            The           1
# 3            Boy           1
# 4     Travellers           1
# 5             in           1
# 6        Mexico,           1
# 7             by           1
# 8         Thomas           1
# 9             W.           1
# 10  Knox\n\nThis           1
# 11         eBook           1
# 12            is           1
# 13           for           1
# 14           the           1
# 15           use           1
# 16            of           1
# 17        anyone           1
# 18      anywhere           1
# 19            in           1

# %%
df_ili.groupby('palabras').count()
# Out:
#            ocurrencia
# palabras
#                 22345
# "'All               1
# "'And               1
# "'DEAR              1
# "'In                2
# ...               ...
# zones,              2
# zones.              1
# zopilote,           1
# à                   3
# ﻿Project            1
#
# [30318 rows x 1 columns]
