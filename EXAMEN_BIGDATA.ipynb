# %%
import pandas as pd
import numpy as np

# %%
# !unzip avocado-prices.zip
# Out:
# Archive:  avocado-prices.zip
#   inflating: avocado.csv

# %%
df = pd.read_csv('avocado.csv', encoding="latin1")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.sort_values(by='AveragePrice', ascending=False)
#1.-PRECIO PROMEDIO MÁS ALTO EN PROPORCIÓN A LOS AGUACATES VENDIDOS ES: -----3.25-----
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 14125           8  2016-10-30          3.25      16700.94     2325.93
# 17428          37  2017-04-16          3.17       3018.56     1255.55
# 14124           7  2016-11-06          3.12      19043.80     5898.49
# 16055          42  2017-03-12          3.05       2068.26     1043.83
# 16720          18  2017-08-27          3.04      12656.32      419.06
# ...           ...         ...           ...           ...         ...
# 1716            0  2015-12-27          0.49    1137707.43   738314.80
# 15262          44  2017-02-26          0.49      44024.03      252.79
# 15473          43  2017-03-05          0.48      50890.73      717.57
# 7412           47  2017-02-05          0.46    2200550.27  1200632.86
# 15261          43  2017-03-05          0.44      64057.04      223.84
#
#             4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
ploteo = df[["Small Bags", "Large Bags", "XLarge Bags"]]

# %%
ploteo.dtypes
# Out:
# Small Bags     float64
# Large Bags     float64
# XLarge Bags    float64
# dtype: object

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(ploteo, kind="reg")
plt.show()
#2.- GRAFIQUE LAS BOLSAS PEQUEÑAS,GRANDES Y EXTRAGRANDES VENDIDAS Y EXPLIQUE LA RESPUESTA PARA AGUACATES ORGÁNICOS Y PARA AGUACATES CONVENCIONALES

#RESPUESTA: Analizando los datos se muestra que se venden mayormente los aguacates orgánicos, existe una gran variedad de ventas en bolsas pequeñas,granes y extragrandes

# %%
df.describe()
#3.- EL PROMEDIO DE BOLSAS VENDIDAS ES:  -----2.396392-----------
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.dtypes
#4.- TIPOS DE ARCHIVOS
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object
